# %%
# %pylab
# Out:
# Using matplotlib backend: agg
# Populating the interactive namespace from numpy and matplotlib

# %%
a = [1, 2, 3, 4]
a = array(a)
b = array([2, 3, 4, 5])
a ** b

a[0]

a[-2:]
a.shape

a.shape = 2,2
a * a
# Out:
# array([[ 1,  4],
#        [ 9, 16]])

# %%
a = linspace(0, 2*pi, 21)
# %precision 3
a

b = sin(a)
b

# %matplotlib inline
plot(a, b)

b >= 0

mask = b >= 0

mask

plot(a[mask], b[mask], 'ro')

# %%
# %matplotlib inline
x = linspace(0, 2 * pi, 50)
x
sin(x)
# plot(sin(x))
# plot(x, sin(x))
# plot(x, sin(x),
#     x, sin(2 * x))

plot(x, sin(x), 'b-o',
    x, sin(2 * x), 'r-^')
# Out:
# [<matplotlib.lines.Line2D at 0x7f5a151b5f10>,
#  <matplotlib.lines.Line2D at 0x7f5a1519af10>]

# %%
x = rand(200)
y = rand(200)
size = rand(200)*30
color = rand(200)
scatter(x, y, size, color)
# 显示颜色条
colorbar()


t = linspace(0, 2*pi, 50)
x = sin(t)
y = cos(t)
figure()
plot(x)
figure()
plot(y)

# %%
plot(x, sin(x))
xlabel('radians')
ylabel('amplitude', fontsize='large')
title('Sin(x)')
grid()

clf() 
close('all')

# %%
from scipy.misc import face
img = face()
img




dir(cm)
imshow(img, cmap=cm.RdGy_r)
show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-7-cbde339225fa> in <module>
# ----> 1 from scipy.misc import face
#       2 img = face()
#       3 img
#       4
#       5
#
# ModuleNotFoundError: No module named 'scipy'

# %%
hist(randn(1000))

# %%
from numpy import *
lst = [0, 1, 2, 3]
a = array(lst)
a
type(a)
# 32比特的整数
a.dtype
a.itemsize
# 1维数组，返回一个元组
a.shape
shape(a)

lst = [1,2,3,4]
shape(lst)
a.size
a.nbytes

a.fill(-4.8)
a

# %%
a = array([[11, 2, 5, 20],
           [1, 2, 11, 15]])
t = a > 10
print t
loc = where(t)
loc

# a[loc]

rows, cols = where(a>10)

rows

# %%
from numpy import *
a = array([1 + 1j, 2, 3, 4])

a.dtype
a.real
a.imag
a.imag = [1,2,3,4]

a.conj()

# %%
person_dtype = np.dtype([('name', 'a4'), ('age', 'int'), ('weight', 'float')])
people = np.empty((3,4), person_dtype)


people

# %%
import numpy as np
import scipy as sp
import matplotlib as mpl
import matplotlib.pyplot as plt

from scipy import linalg, optimize

np.info(optimize.fmin)

np.lookfor("resize array")

# %%
from ctypes import util, CDLL


libc_name = util.find_library('m')

# on WINDOWS
print libc_name
libc = CDLL(libc_name)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

x = [-2, 2, -2, 2]
y = [-4, 4, 0.5, 2.5]

fig = plt.figure()
plt.axhline(y=0, c='black')
plt.axvline(x=0, c='black')

plt.plot(x[:2], y[:2], x[2:], y[2:])

plt.draw()

# %%
from functools import partial

fig = plt.figure()
plt.axhline(y=0, c='black')
plt.axvline(x=0, c='black')
ax = plt.gca()
ax.set_xlim(-2.5, 2.5)
ax.set_ylim(-3, 4)

arrow_vector = partial(plt.arrow, width=0.01, head_width=0.1, head_length=0.2, length_includes_head=True)

arrow_vector(0, 0, 2, -1, color='g')
arrow_vector(0, 0, -1, 2, color='c')
arrow_vector(2, -1, -2, 4, color='b')
arrow_vector(0, 0, 0, 3, width=0.05, color='r')

plt.draw()
